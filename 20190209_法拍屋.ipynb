# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup

# %%
pwd
# Out:
# 'C:\\Users\\Elisa\\Documents'

# %%
my_url='http://aomp.judicial.gov.tw/abbs/wkw/WHD2A03.jsp?pageTotal=15&pageSize=15&rowStart=16&saletypeX=1&proptypeX=C52&courtX=TPD&order=odcrm&query_typeX=session&saleno=&hsimun=all&ctmd=all&sec=all&crmyy=&crmid=&crmno=&dpt=&saledate1=&saledate2=&minprice1=&minprice2=&sumprice1=&sumprice2=&area1=&area2=&registeno=&checkyn=all&emptyyn=all&order=odcrm&owner1=&landkd=&rrange=%A4%A3%A4%C0&comm_yn=&stopitem=&courtNoLimit=&pageNow=1&448E72A83D10F28564E105D867E6CB76=12161D65F5F9E160D8F4EB4FC08A65C3'

# %%
uClient =uReq(my_url)   #open html and srart to craw 
page_html = uClient.read()
uClient.close()
page_soup= soup(page_html,'html.parser')  # html parser

# %%
page_soup.head  #會把head 下面的全部都展開
# Out:
# <head>
# <title>法拍屋查詢系統</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type">
# <script src="/abbs/resource/js/jquery/jquery-1.11.3.min.js" type="text/javascript"></script>
# <link href="../image/css.css" rel="stylesheet" type="text/css">
# <script language="javascript" src="../script/WINDOW.js"></script>
# <script language="JavaScript">
# <!--
# function MM_swapImgRestore() { //v3.0
#   var i,x,a=document.MM_sr; for(i=0;a&&i<a.length&&(x=a[i])&&x.oSrc;i++) x.src=x.oSrc;
# }
#
# function MM_preloadImages() { //v3.0
#   var d=document; if(d.images){ if(!d.MM_p) d.MM_p=new Array();
#     var i,j=d.MM_p.length,a=MM_preloadImages.arguments; for(i=0; i<a.length; i++)
#     if (a[i].indexOf("#")!=0){ d.MM_p[j]=new Image; d.MM_p[j++].src=a[i];}}
# }
#
# function MM_findObj(n, d) { //v4.0
#   var p,i,x;  if(!d) d=document; if((p=n.indexOf("?"))>0&&parent.frames.length) {
#     d=parent.frames[n.substring(p+1)].document; n=n.substring(0,p);}
#   if(!(x=d[n])&&d.all) x=d.all[n]; for (i=0;!x&&i<d.forms.length;i++) x=d.forms[i][n];
#   for(i=0;!x&&d.layers&&i<d.layers.length;i++) x=MM_findObj(n,d.layers[i].document);
#   if(!x && document.getElementById) x=document.getElementById(n); return x;
# }
#
# function MM_swapImage() { //v3.0
#   var i,j=0,x,a=MM_swapImage.arguments; document.MM_sr=new Array; for(i=0;i<(a.length-2);i+=3)
#    if ((x=MM_findObj(a[i]))!=null){document.MM_sr[j++]=x; if(!x.oSrc) x.oSrc=x.src; x.src=a[i+2];}
# }
#
# function display(filenm){
# 		var width = 700;
# 		var height = 480;
# 		//alert("display filenm: " + filenm);
# 		openDialog(filenm,arguments,width,height,1);
# 	}
#
#
#
# //進入水利網
# function gotoEPA(county,town,land1,land2,landno){
#
# 	//有水利網 用 window.open 有問題
# 	var param = 'county=' + county + '&town=' + town + '&land1='+ land1 +'&land2='+ land2 +'&landno='+landno;
#
# 	var epa =openwin1('https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx',param,1024,768);
#
# 	//window.open(' 新視窗的網址 ', '新視窗的名稱', config='height=高度,width=寬度');
# }
#
#
#
# function openWHD2ASHOW(rowid){
# 		 try {
# 		   var type = "aaaa";
# 		   var features = "height=550,width=800,toolbar=no,scrollbars=yes";
# 			  window.open("", type, features, "true");
# 			   form3.rowid.value = rowid;
#
# 			  form3.target = type;
# 	   			form3.submit();
#
#
# 		 }catch(e) {
# 		  alert("請先將之前開啟之畫面關閉，才能正常開啟");
# 		 }
# }
#
# //將
# function doChangeAction(){
# 	form.action='WHD2A03.jsp';
# }
#
# function  doExcel(){
#       			form.action = 'WHD2A03_DOWNLOAD.jsp';
#       			form.submit();
#       		}
#
#       		function returnWHD2A00(){
#
#       				location.href='WHD2A00.jsp';
#
#       				//form.action='WHD2A00.jsp';
#       				//form.submit();
#
#       		}
# //-->
# </script>
# </link></meta></head>

# %%
page_soup.body.table  #這裡有我想要的，重點是我要怎麼找到想要的值
# Out:
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="98%">
# <tr>
# <td width="0%"> </td>
# <td width="98%">
# <div align="center"></div>
# </td>
# <td width="2%"> </td>
# </tr>
# <tr>
# <td colspan="3"> </td>
# </tr>
# <tr>
# <td width="0%"> </td>
# <td bgcolor="#FFFFFF" width="98%"><img alt="" height="1" src="../image/line.gif" width="1">
# <table style="margin:0 0 0 0" width="100%">
# <tr>
# <td align="left">
# 					   依案號排序
#
#
#
# 					</td>
# <td align="right">
# <input name="downloadExcel" onclick="doExcel()" type="button" value="查詢結果另存Excel">
# <input name="fffff" onclick="returnWHD2A00()" type="button" value="回首頁">
# </input></input></td>
# </tr>
# </table>
# </img></td>
# <td width="2%">   </td>
# </tr>
# <tr>
# <td bgcolor="#FFFFFF" width="0%"> </td>
# <td width="98%">
# <table border="1" cellpadding="0" cellspacing="0" width="100%">
# <tr>
# <td class="head" width="5%">
# <div align="center">筆次</div></td>
# <td class="head" width="5%">
# <div align="center">法院名稱</div></td>
# <td class="head" width="15%">
# <div align="center">字號<br>
#                 股別</br></div></td>
# <td class="head" width="10%">
# <div align="center">拍賣日期<br>
#
#                  	拍賣次數
#
#
#                </br></div></td>
# <td class="head" width="7%">
# <div align="center">縣市</div></td>
# <td class="head" width="20%">
# <div align="center">
#                 房屋地址/樓層面積
#
#                 </div></td>
# <td class="head">總拍賣底價(元)</td>
# <td class="head" width="6%">
# <div align="center">點交</div>
# </td>
# <td class="head" width="5%">
# <div align="center">空屋
# </div>
# </td>
# <td class="head" width="5%">
# <div align="center">標 別</div>
# </td>
# <td class="head" width="7%">
# <div align="center">備 註</div>
# </td>
# <td class="head">
# <div align="center">看圖</div>
# </td>
# <td class="head">
# <div align="center">採通訊投標</div>
# </td>
# <td class="head">
# <div align="center">土地有無<br>遭受污染</br></div>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">1</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">100司執字第  56459號<br>
#
#               (丁股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/26<br>
#
#
#                  第2拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 松山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F29162818979.002" target="_blank">
#               台北市松山區八德路3段155巷2之2號7樓
#
#               </a>
# <br>
#                   25
# 坪　x　全部
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 2,480,000 元
#
#
#
#
#             </br></br></td>
# <td> 19,040,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
#
# 	      </div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('100','司執','056459','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E6%9D%BE%E5%B1%B1%E5%8D%80&amp;land1=%E7%BE%8E%E4%BB%81&amp;land2=%E4%BA%8C&amp;landno=485">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">2</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">104司執字第  35967號<br>
#
#               (甲股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/25<br>
#
#
#                  第1拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中正區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F06122149127.018" target="_blank">
#               羅斯福路一段43、45、47號
#
#               </a>
# <br>
#                   150
# 坪　x　全部
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 550,000 元
#
#
#
#
#             </br></br></td>
# <td> 550,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F18143237035.018" target="_blank">更正公告</a>
#
# 	      </div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('104','司執','035967','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E6%AD%A3%E5%8D%80&amp;land1=%E5%8D%97%E6%B5%B7&amp;land2=%E4%B8%80&amp;landno=719">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">3</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">104司執字第148008號<br>
#
#               (福股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/18<br>
#
#
#                  第2拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F18174211743.041" target="_blank">
#               台北市中山區雙城街17巷13之3號
#
#               </a>
# <br>
#                   21
# 坪　x　1分之1
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 1,230,000 元
#
#
#
#
#             </br></br></td>
# <td> 25,560,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
#
# 	      </div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('104','司執','148008','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E4%B8%AD%E5%B1%B1&amp;land2=%E4%B8%80&amp;landno=406">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">4</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">104司執字第148008號<br>
#
#               (福股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/18<br>
#
#
#                  第2拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F18174211743.041" target="_blank">
#               台北市中山區雙城街17巷13之3號地下一層
#
#               </a>
# <br>
#                   27
# 坪　x　1分之1
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 1,130,000 元
#
#
#
#
#             </br></br></td>
# <td> 25,560,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
#
# 	      </div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('104','司執','148008','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E4%B8%AD%E5%B1%B1&amp;land2=%E4%B8%80&amp;landno=406">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">5</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">105司執字第126863號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第3拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F19095918020.046" target="_blank">
#               台北市中山區林森北路119巷81號
#
#               </a>
# <br>
#                   14
# 坪　x　全部
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 5,200,000 元
#
#
#
#
#             </br></br></td>
# <td> 25,000,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#               		甲
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10802%2F13153258120.046" target="_blank">停拍公告</a><br>
#
#
# 	      </br></div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('105','司執','126863','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E6%AD%A3%E7%BE%A9&amp;land2=%E4%B8%80&amp;landno=113">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">6</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">105司執字第126863號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第3拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F19095918020.046" target="_blank">
#               台北市中山區林森北路119巷81號4樓之5
#
#               </a>
# <br>
#                   2
# 坪　x　19分之1
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 1,200,000 元
#
#
#
#
#             </br></br></td>
# <td> 25,000,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#               		甲
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10802%2F13153258120.046" target="_blank">停拍公告</a><br>
#
#
# 	      </br></div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('105','司執','126863','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E6%AD%A3%E7%BE%A9&amp;land2=%E4%B8%80&amp;landno=113">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">7</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">105司執字第126863號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第3拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F19095918020.046" target="_blank">
#               台北市中山區中山北路一段121巷23號
#
#               </a>
# <br>
#                   12
# 坪　x　全部
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 7,730,000 元
#
#
#
#
#             </br></br></td>
# <td> 102,290,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#               		2
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10802%2F13153258120.046" target="_blank">停拍公告</a><br>
#
#
# 	      </br></div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('105','司執','126863','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E6%AD%A3%E7%BE%A9&amp;land2=%E4%B8%89&amp;landno=177">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">8</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">105司執字第126863號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第3拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F19095918020.046" target="_blank">
#               台北市中山區林森北路85巷7號
#
#               </a>
# <br>
#                   23
# 坪　x　全部
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 8,000,000 元
#
#
#
#
#             </br></br></td>
# <td> 38,120,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#               		1
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10802%2F13153258120.046" target="_blank">停拍公告</a><br>
#
#
# 	      </br></div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('105','司執','126863','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E6%AD%A3%E7%BE%A9&amp;land2=%E4%BA%8C&amp;landno=325">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">9</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">105司執字第126863號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第3拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F19095918020.046" target="_blank">
#               台北市中山區中山北路一段121巷19號地下一層
#
#               </a>
# <br>
#                   7
# 坪　x　全部
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 8,350,000 元
#
#
#
#
#             </br></br></td>
# <td> 102,290,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#               		2
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10802%2F13153258120.046" target="_blank">停拍公告</a><br>
#
#
# 	      </br></div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('105','司執','126863','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E6%AD%A3%E7%BE%A9&amp;land2=%E4%B8%89&amp;landno=177">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">10</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">105司執字第126863號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第3拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F19095918020.046" target="_blank">
#               台北市中山區中山北路一段121巷19號
#
#               </a>
# <br>
#                   1
# 坪　x　8分之2
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 17,090,000 元
#
#
#
#
#             </br></br></td>
# <td> 102,290,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#               		2
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10802%2F13153258120.046" target="_blank">停拍公告</a><br>
#
#
# 	      </br></div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('105','司執','126863','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E6%AD%A3%E7%BE%A9&amp;land2=%E4%B8%89&amp;landno=177">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">11</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">105司執字第126863號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第3拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 中山區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F19095918020.046" target="_blank">
#               台北市中山區中山北路一段121巷21號
#
#               </a>
# <br>
#                   13
# 坪　x　全部
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 8,260,000 元
#
#
#
#
#             </br></br></td>
# <td> 102,290,000 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#               		2
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10802%2F13153258120.046" target="_blank">停拍公告</a><br>
#
#
# 	      </br></div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('105','司執','126863','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E4%B8%AD%E5%B1%B1%E5%8D%80&amp;land1=%E6%AD%A3%E7%BE%A9&amp;land2=%E4%B8%89&amp;landno=177">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">12</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">105司執助字第    9745號<br>
#
#               (平股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/21<br>
#
#
#                  第4拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">臺北市<br>
#                 大安區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F15163824740.013" target="_blank">
#               忠孝東路四段112號地下樓
#
#               </a>
# <br>
#                   310
# 坪　x　10000分之68
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 333,000 元
#
#
#
#
#             </br></br></td>
# <td> 1,163,000 </td>
# <td width="6%">
# <div align="center">不點交</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
#
# 	      </div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('105','司執助','009745','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E8%87%BA%E5%8C%97%E5%B8%82&amp;town=%E5%A4%A7%E5%AE%89%E5%8D%80&amp;land1=%E5%BE%A9%E8%88%88&amp;land2=%E4%BA%8C&amp;landno=35">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">13</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">106司執字第  74124號<br>
#
#               (木股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/20<br>
#
#
#                  第2拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">新北市<br>
#                 新店區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10801%2F23163351483.037" target="_blank">
#               新北市新店區寶宏路20號三樓
#
#               </a>
# <br>
#                   26
# 坪　x　1分之1
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 2,360,000 元
#
#
#
#
#             </br></br></td>
# <td> 6,040,000 </td>
# <td width="6%">
# <div align="center">點交</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
#
# 	      </div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('106','司執','074124','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E6%96%B0%E5%8C%97%E5%B8%82&amp;town=%E6%96%B0%E5%BA%97%E5%8D%80&amp;land1=%E5%AF%B6%E6%A9%8B&amp;land2=&amp;landno=337">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">14</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">106司執字第104665號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第1拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">新北市<br>
#                 新店區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10712%2F28140320820.046" target="_blank">
#               新北市新店區黎明路118號地下一、二層
#
#               </a>
# <br>
#                   713
# 坪　x　64分之2
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 1,530,000 元
#
#
#
#
#             </br></br></td>
# <td> 25,052,100 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
#
# 	      </div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('106','司執','104665','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E6%96%B0%E5%8C%97%E5%B8%82&amp;town=%E6%96%B0%E5%BA%97%E5%8D%80&amp;land1=%E9%BB%8E%E6%98%8E&amp;land2=&amp;landno=494">查詢</a>
# </td>
# </tr>
# <tr>
# <td class="head" width="5%">
# <div align="center">15</div></td>
# <td width="5%">
# <div align="center">
#               臺灣台北地方法院
# 			  </div></td>
# <td width="15%">106司執字第104665號<br>
#
#               (佳股)
#
#
#
#             </br></td>
# <td width="10%">
# <div align="center">108/02/22<br>
#
#
#                  第1拍
#
#
#
#               </br></div>
# </td>
# <td width="7%">
# <div align="center">新北市<br>
#                 新店區</br></div>
# </td>
# <td width="20%">
# <a href="WHD2ASHOW.jsp?rowid=%2Ftpd%2F10712%2F28140320820.046" target="_blank">
#               新北市新店區黎明路120號15樓
#
#               </a>
# <br>
#                   55
# 坪　x　全部
#
#
#
#
#                		<br>建物拍賣底價: 新台幣 5,980,000 元
#
#
#
#
#             </br></br></td>
# <td> 25,052,100 </td>
# <td width="6%">
# <div align="center">如備註或使用情形欄所示</div>
# </td>
# <td width="5%">
# <div align="center">
#
#
#
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="5%">
# <div align="center">
#
#
#               </div>
# </td>
# <!--         	//modified by Ender 08/08/25[ Bug #3306 - ULD0EC0970002 ]	 -->
# <td width="7%">
# <div align="center">
#
# 	      </div>
# </td>
# <td width="5%"><a href="#" onclick="javascript:lookPic('106','司執','104665','TPD');" title="看拍賣物圖片">看照片</a></td>
# <td>
# <center>
#             	否
#
#             </center>
# </td>
# <td>
# <a href="https://sgw.epa.gov.tw/public/ContaminatedSitesMap/Default.aspx?county=%E6%96%B0%E5%8C%97%E5%B8%82&amp;town=%E6%96%B0%E5%BA%97%E5%8D%80&amp;land1=%E9%BB%8E%E6%98%8E&amp;land2=&amp;landno=494">查詢</a>
# </td>
# </tr>
# </table>
# </td>
# <td bgcolor="#FFFFFF" width="2%"> </td>
# </tr>
# <tr>
# <td width="0%"> </td>
# <td bgcolor="#FFFFFF" width="98%"><img alt="" height="1" src="../image/line.gif" width="1"/></td>
# <td width="2%"> </td>
# </tr>
# </table>

# %%
#rows = soup.find_all('div', class_='tr')  <div align="center">筆次</div>
page_soup.findAll('div', align="center")[1]
page_soup.findAll('div', align="center")[1].text   #o:'筆次'    終於抓到筆 感動  嗚嗚嗚


#應該可以抓整個table 下來
# Out:
# '筆次'

# %%
#findAll("div",{"class":"item-container"}) 
page_soup.findAll("td",{"class":"head"})[0]  
page_soup.findAll("td",{"class":"head"})[13]  #可以抓到13個欄位 但對我沒甚麼幫助
# Out:
# <td class="head">
# <div align="center">土地有無<br>遭受污染</br></div>
# </td>

# %%
#shipping_containcontainer[0].text.strip()
page_soup.findAll('tr')[5].text    #欄位哪一欄
page_soup.findAll('tr')[6].text    #第一筆資廖
# Out:
# '\n\n1\n\n\r\n              臺灣台北地方法院\r\n\t\t\t  \n100司執字第\xa0\xa056459號\r\n            \r\n              (丁股)\r\n            \r\n\r\n\r\n            \n\n108/02/26\r\n              \r\n\r\n                 第2拍\r\n              \r\n              \r\n\r\n              \n\n\n臺北市\r\n                松山區\n\n\n\r\n              台北市松山區八德路3段155巷2之2號7樓\n\r\n              \n\r\n                  25\n坪\u3000x\u3000全部\r\n                  \t\r\n              \r\n              \r\n              \t \r\n               \t\t建物拍賣底價: 新台幣 2,480,000 元\r\n               \t\r\n              \r\n             \r\n             \r\n            \n 19,040,000 \n\n如備註或使用情形欄所示\n\n\n\r\n\r\n\r\n\t      \xa0\xa0\n\r\n\r\n              \n\n\n\n\r\n              \t\xa0\r\n              \t\t\t\t\t\r\n              \n\n\n\n\r\n                \xa0\r\n\t      \n\n看照片\n\n\r\n            \t否\n\r\n            \n\n\n查詢\n\n'

# %%
page_soup.findAll('tr')
for record in page_soup.findAll('tr'):
    #print(record.text)
    #record_2=record.text#.replace("\n","")
    record.text
    print(record_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-73585f04c909> in <module>()
#       4     #record_2=record.text#.replace("\n","")
#       5     record.text
# ----> 6     print(record_2)
#       7
#
# NameError: name 'record_2' is not defined

# %%
#我只需要抓到值就好 欄位名稱之後自己去寫死
page_soup.findAll("table")
page_soup.findAll('div', align="center")[16]  #
page_soup.findAll('div', align="center")[16].text  #可以抓 日期 跟第幾拍
page_soup.findAll('div', align="center")[24].text   #可以抓 日期 跟第幾拍
page_soup.findAll('div', align="center")[32].text
# Out:
# '108/02/18\r\n              \r\n\r\n                 第2拍\r\n              \r\n              \r\n\r\n              '
